# %%
import pandas as pd

# %%
df1 =pd.read_csv('20161006.csv',lineterminator='\n',skipinitialspace=True, usecols= ['text'])
df2 =pd.read_csv('20161007.csv',lineterminator='\n',skipinitialspace=True, usecols= ['text'])
frame = [df1, df2]
df = pd.concat(frame)
df.shape

# %%
df.rename(columns={'text':'Tweet'}, inplace=True)
import os

# %%
df
# Out:
#                                                      Tweet
# 0        역삼러샤출장 ★달콤백마★감동가격\n전화▷010♥2156♥6232◁\n#개룡출장샵\n...
# 1        あ、星付いた！ ( @mn_dance313 ダンスの前！！ https://t.co/Lt...
# 2        Facebook Video 10210687778127621 https://t.co/...
# 3                                          メタル甲虫装機とか面白そうやね
# 4        RT @BTS_twt: BIG PUMA\n#bogsock https://t.co/2...
# 5        RT @StylishRentals: Some pretty sweet mens cuf...
# 6                                     @msbf77 照れる🌾(？)(拭いて)
# 7                        @_Benjamin17 LMAO ihy u right tho
# 8        @Kumbalov спасибо 😉Да я же вроде не страдаю ун...
# 9        @yonggi0707 헉ㄱ온네 아픈거야???!?!??!?!?!?!?!?!?!!?!?...
# 10          にしても\n60円で幸せを作り出すおばちゃん、もといお肉屋さんに感動した。\nまた行こうっと
# 11                                       @kagari97 やめなさい！w
# 12       RT @BTS_twt: BIG PUMA\n#bogsock https://t.co/2...
# 13       池坂さんは 冷やし中華始めました\n#しゃうさぎ鍋作るよ\nhttps://t.co/sOr...
# 14       RT @BTS_twt: BIG PUMA\n#bogsock https://t.co/2...
# 15       RT @silphyd: 리) 요즘 궁에 어울리는 한복... 같은 헛소리가 자꾸 들리...
# 16       احد ابطالنا اثناء التمرين 👍🏼\n#اكاديمية_اكشن #...
# 17       RT @vbv799: ▪ صغار العقول\n🔎 يرون الاعتذار\n ⏳...
# 18       ごめんね先生〜〜〜〜〜😂😂\n最初のイメージ悪かった分ほんとに上がる一方だったよ〜〜〜〜よか...
# 19       RT @BTS_twt: BIG PUMA\n#bogsock https://t.co/2...
# 20       RT @Di_Jjyan: 무인양품 깃털베개 후기 -&gt; 사지 마세요; 너무 편안...
# 21       RT @evulmatzee: Повеќе Евгениј Онегин, помалку...
# 22       @Bussaraporn5 ตั้งแต่เช้ายังไม่ได้ลุกเลยนะ5555...
# 23        BL本の注文しながら気付いたんだけど、最近のBLコミック、文庫小説価格と並ぶくらいになってきた。
# 24       @brvndonhvuer hello I used to take a music the...
# 25       @dramaticselling 네 감사합니다. 거래 끝날 때까지 맞팔 부탁드려도 괜...
# 26       RT @al_awashii: واعلانهم انقلب عليهم😂\n #راح_ن...
# 27       RT @BTS_twt: BIG PUMA\n#bogsock https://t.co/2...
# 28        鏡越しでこちらを見る猫。笑 https://t.co/TOZxoCEJ7m @24ayuchin
# 29       RT @jom5s: Eh....Ma la Belen! ..... Povera Ita...
# ...                                                    ...
# 2565859                                                NaN
# 2565860                                                NaN
# 2565861                                                NaN
# 2565862                                                NaN
# 2565863                                                NaN
# 2565864                                                NaN
# 2565865                                                NaN
# 2565866                                                NaN
# 2565867                                                NaN
# 2565868                                                NaN
# 2565869                                                NaN
# 2565870                                                NaN
# 2565871                                                NaN
# 2565872                                                NaN
# 2565873                                                NaN
# 2565874                                                NaN
# 2565875                                                NaN
# 2565876                                                NaN
# 2565877                                                NaN
# 2565878                                                NaN
# 2565879                                                NaN
# 2565880                                                NaN
# 2565881                                                NaN
# 2565882                                                NaN
# 2565883                                                NaN
# 2565884                                                NaN
# 2565885                                                NaN
# 2565886                                                NaN
# 2565887                                                NaN
# 2565888                                                NaN
#
# [3460423 rows x 1 columns]

# %%
#Set the path to the data folder, datafile and output folder and files
root_folder = '/users/kent/jmaharja/drugAbuse'
# data_folder = os.path.abspath(os.path.join(root_folder, 'datasets/text_gen_product_names'))
model_folder = os.path.abspath(os.path.join(root_folder, 'output/Drug-Abuse/RoBERTaMLM/'))
output_folder = os.path.abspath(os.path.join(root_folder, 'output/Drug-Abuse'))
tokenizer_folder = os.path.abspath(os.path.join(root_folder, 'output/Drug-Abuse/TokRoBERTa/'))

# test_filename='Tweets_Spring_Summer_2021_coded'
# datafile= 'product_names_desc_cl_train.csv'
outputfile = 'submission.csv'

# datafile_path = os.path.abspath(os.path.join(data_folder,datafile))
# testfile_path = os.path.abspath(os.path.join(data_folder,test_filename))
outputfile_path = os.path.abspath(os.path.join(output_folder,outputfile))
